# %%
#Data Analysis with Pandas

# %%
#Benefits - efficient data handling, powerful data transformation, faciltate EDA, enables data aggregation and summ

# %%
#Limitations - memory usage and performance, limited parallel processing, limited support for time series analysis, not optimized for large scale distributed computing

# %%
#concepts - importing, selecting, filtering, aggregating, visualization

# %%
#reading material https://drive.google.com/file/d/1EhvqUR9-bji2D1Viu5aTjWGMBZFwDduQ/view?usp=sharing

# %%
#Pandas is designed to work with in-memory data, and as the size of the dataset increases, it can lead to memory constraints and performance bottlenecks.

#Apache Spark, on the other hand, is built for distributed computing, allowing it to handle large-scale data by distributing it across a cluster of machines. This distributed approach helps overcome the limitations of memory usage and enhances performance for big data processing.

# %%
#Pandas can optimize memory usage when working with large datasets by using the astype() method to convert data types to more memory efficient ones.

#For example, we may read in data where all columns are strings. We can convert numeric columns to floats or integers which use less memory. Categorical columns can be converted to category dtype.

# %%
#Practice Resource

# %%
import pandas as pd

# %%
df = pd.read_excel("https://bit.ly/retail_store_ds")

# %%
df.head()
# Out:
#    ProductID ProductName  Category  Price  QuantitySold
# 0          1       Apple   Produce    0.5           100
# 1          2      Banana   Produce    0.3           150
# 2          3      Carrot   Produce    0.7            80
# 3          4   Detergent  Cleaning    5.0            50
# 4          5        Eggs     Dairy    2.0           120

# %%
df = pd.read_csv(r"https://colab.research.google.com/corgiredirector?site=https%3A%2F%2Fafterwork.ai%2Fds%2Fch%2Fretail_store_1jtq.csv")

# %%
df.head()
# Out:
#   <!DOCTYPE html><html lang="en"><meta name="referrer" content="origin"/><meta name="viewport" content="width=device-width  \
# 0                                               try{
# 1  _._F_toggles_initialize=function(a){("undefine...
# 2                                                 /*
# 3             Copyright The Closure Library Authors.
# 4                SPDX-License-Identifier: Apache-2.0
#
#    initial-scale=1"><title>Leaving Google Colab</title><link href="https://fonts.googleapis.com/css2?family=Google+Symbols:FILL@0..1&display=block" rel="stylesheet"><link href="https://fonts.googleapis.com/css?family=Roboto:300  \
# 0                                                NaN
# 1                      _._F_toggles_initialize)([]);
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    400  500  600 700|Google+Sans:300 400.1 500.1 600.1  \
# ...

# %%
# Load the dataset
df = pd.read_csv(r'https://afterwork.ai/ds/e/retail_store_srghf.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\anaconda3\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\anaconda3\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
# Load the dataset
df = pd.read_csv('https://afterwork.ai/ds/e/retail_store_bqfht.csv')

# Preview the dataset
df.head()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\anaconda3\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\anaconda3\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
# Import the Matlotlib library to perform data visualization

import matplotlib.pyplot as plt

# %%
import ssl

# This restores the same behavior as before.
context = ssl._create_unverified_context()
urllib.urlopen("https://no-valid-cert", context=context)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       3 # This restores the same behavior as before.
#       4 context = ssl._create_unverified_context()
# ----> 5 urllib.urlopen("https://no-valid-cert", context=context)
#
# NameError: name 'urllib' is not defined

# %%
df = pd.read_csv("https://afterwork.ai/ds/ch/retail_store_xrku.csv")
df.head()
